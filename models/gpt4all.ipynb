# %%
import langchain.embeddings

# %%
from gpt4all import GPT4All, Embed4All
embedder = Embed4All()
output = embedder.embed("Hello World")
# Out:
# 100%|██████████| 45.5M/45.5M [00:02<00:00, 21.5MiB/s]
# Model downloaded at:  /home/uniqueusman/.cache/gpt4all/ggml-all-MiniLM-L6-v2-f16.bin

# %%
print(output)
# Out:
# [0.0005084243603050709, 0.020542150363326073, 0.027368685230612755, -0.008136625401675701, -0.010209380649030209, -0.12848474085330963, 0.024221302941441536, -0.051339298486709595, -0.0691557228565216, 0.004235498607158661, 0.04535206779837608, 0.016009194776415825, 0.018917260691523552, -0.012394758872687817, 0.020242871716618538, -0.02523789368569851, 0.03880549222230911, -0.04834321141242981, -0.1273297369480133, 0.0043710218742489815, 0.009456071071326733, 0.04828261211514473, -0.005551530979573727, 0.03508443385362625, -0.07722115516662598, -0.01412164606153965, 0.02374606765806675, 0.0678521916270256, 0.02432965114712715, -0.047614723443984985, 0.016456173732876778, -0.002399337012320757, 0.1458861380815506, -0.0314476415514946, 0.03387343883514404, 0.0573447160422802, -0.012856823392212391, -0.07295098155736923, -0.07106567174196243, 0.02598900906741619, 0.037848614156246185, -0.07440692186355591, 0.0012012210208922625, 0.025354916229844093, -0.04250705987215042, -0.0068164658
# ...
